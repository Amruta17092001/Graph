# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
np.random.randn(1000)
# Out:
# array([-5.88466194e-01, -1.57749656e+00, -4.34700909e-01, -2.52227673e+00,
#        -1.03074146e+00, -9.33828678e-01,  1.72377229e-01, -2.05114298e-01,
#         7.00414896e-01, -4.21421719e-02,  1.92398220e+00, -1.14124476e+00,
#         1.57086423e+00, -3.64044394e-01,  1.54781378e+00,  1.25254517e-01,
#        -1.17249470e+00, -1.14258782e+00,  2.34320019e-01,  2.75274494e-01,
#        -1.82241359e+00, -1.02649658e+00, -1.10721070e+00, -2.39705362e-01,
#        -7.26667619e-01,  1.10903072e-01, -6.99444925e-02,  5.67301257e-01,
#        -7.21266693e-01, -1.35788967e+00, -1.76911629e+00,  8.92368549e-01,
#         8.36770254e-01,  6.94562984e-01,  1.29694508e-01,  6.30538952e-01,
#         4.37228726e-01, -1.39164440e+00,  1.85164429e+00, -1.46962414e-01,
#         1.44177382e+00,  4.85956065e-01, -2.01903179e+00,  1.03740055e-02,
#        -1.73490638e+00, -1.45894928e-01, -4.39260232e-01,  1.67066410e+00,
# ...

# %%
# convert the above dataset into dataframe
pd.DataFrame(np.random.randn(1000))
# Out:
#             0
# 0   -1.150971
# 1    0.257682
# 2   -0.158591
# 3    1.586033
# 4   -0.421534
# ..        ...
# 995  2.005295
# 996  1.172089
# 997  0.647399
# 998 -0.486058
# 999  0.774637
#
# [1000 rows x 1 columns]

# %%
# Give the column name using columns = ['....']
pd.DataFrame(np.random.randn(1000), columns= ['Data'])
# Out:
#          Data
# 0    0.494423
# 1    0.596111
# 2    1.013755
# 3   -0.025093
# 4    0.384135
# ..        ...
# 995 -0.946889
# 996  0.657989
# 997  1.538050
# 998 -0.789797
# 999  1.185153
#
# [1000 rows x 1 columns]

# %%
# Explain the pattran of a dataset 0,1,2,3...999,1000.
# we can't do that

# %%
df = pd.DataFrame(np.random.randn(1000), columns= ['Data'])
df.plot()
# Out:
# <AxesSubplot:>

# %%
 # detile the index

# %% [markdown]
# #### If want to drop any column from the data then
# #### df.drop('column name')
# #### and if it is row then
# ##### df.drop('row name', axis = 1)

# %%
# 3d, 2d and all graph
# mathphotlib is old library
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
np.random.randn(1000) # it is going to array of 1000 dataset (random dataset)
# Out:
# array([ 5.79570727e-01,  5.92952823e-01, -6.00123099e-01, -1.01913933e+00,
#        -6.39722313e-01, -7.20924430e-01, -4.66247754e-01, -4.58718037e-01,
#        -6.78092550e-01, -1.15944459e+00, -1.78546504e+00,  8.09402835e-02,
#        -6.68553554e-01,  3.39679042e-01,  5.88060391e-01, -1.98676211e-01,
#        -4.54278649e-02,  2.98710394e-01, -3.09618504e-01,  1.53647542e+00,
#        -3.21945433e-01,  1.82106180e+00,  1.14033174e+00,  1.12625897e+00,
#         3.07398375e-01,  2.47289044e-01, -9.64752811e-01,  7.15963061e-01,
#         1.09750244e+00, -1.67547177e+00,  1.78593599e-01,  4.30000640e-01,
#         3.67994866e-01,  7.55122817e-01, -1.18552125e+00, -5.47989059e-01,
#        -5.87890017e-01,  4.74048140e-01, -3.91427391e-01,  5.03997714e-01,
#        -4.70994304e-01,  8.38764255e-01,  7.03026966e-02, -9.70798889e-03,
#        -1.30537417e+00, -1.17094379e+00, -4.76561874e-01, -4.07245485e-01,
# ...

# %%
pd.DataFrame(np.random.randn(1000),columns=['data'])
# Out:
#          data
# 0   -0.098037
# 1    0.445414
# 2    1.112021
# 3   -0.445726
# 4    1.133719
# ..        ...
# 995  0.518541
# 996  1.246190
# 997  1.582733
# 998 -0.733698
# 999 -1.030188
#
# [1000 rows x 1 columns]

# %%
df=pd.DataFrame(np.random.randn(1000),columns=['data'])

# %%
df
# Out:
#          data
# 0   -0.099871
# 1   -0.224889
# 2   -0.291910
# 3    0.692744
# 4    0.405824
# ..        ...
# 995 -0.517036
# 996  1.022042
# 997  0.500509
# 998 -0.616043
# 999 -0.624725
#
# [1000 rows x 1 columns]

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df.plot(figsize=(20,10))
# Out:
# <AxesSubplot:>

# %%
df1 = pd.read_csv('https://gist.githubusercontent.com/curran/a08a1080b88344b0c8a7/raw/0e7a9b0a5d22642a06d3d5b9bcbad9890c8ee534/iris.csv')

# %%
df1
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df1.plot()
# Out:
# <AxesSubplot:>

# %%
# for drop id column
df1.drop('Id',axis = 1)    # before i've practice on different dataset thats why it shows error
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13176/468797263.py in <module>
#       1 # for drop id column
# ----> 2 df1.drop('Id',axis = 1)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %%
df1.plot()    # we need to store above df1 in another dataframe see next step

# %%
df2 = df1.drop('Id',axis = 1)

# %%
df2.plot()

# %%
df1.plot(figsize = (20,10)) # I've change df2 as df1 for further no any essue
# Out:
# <AxesSubplot:>

# %%
print('hoi')

# %%
df1.plot(kind='bar',figsize = (20,10))
# Out:
# <AxesSubplot:>

# %%
# select the dataset from 5 to 11
df1.iloc[5:11]
# Out:
#     sepal_length  sepal_width  petal_length  petal_width species
# 5            5.4          3.9           1.7          0.4  setosa
# 6            4.6          3.4           1.4          0.3  setosa
# 7            5.0          3.4           1.5          0.2  setosa
# 8            4.4          2.9           1.4          0.2  setosa
# 9            4.9          3.1           1.5          0.1  setosa
# 10           5.4          3.7           1.5          0.2  setosa

# %%
df1.iloc[5:11].plot(kind='bar',figsize=(20,10))
# Out:
# <AxesSubplot:>

# %%
df1.iloc[5:11].plot(kind='barh',figsize=(20,10))
# Out:
# <AxesSubplot:>

# %%
# for the Histogram
df1.plot(kind="hist")
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df1['sepal_length'].plot(kind='hist')  # on x-axis it always try to represent data range
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
# horizontal histogram
df1['sepal_length'].plot(kind='hist',orientation = "horizontal")
# Out:
# <AxesSubplot:xlabel='Frequency'>

# %%
df1
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df1.hist(figsize=(20,10)) # x-axis = Range and y-axis= frequency
# Out:
# array([[<AxesSubplot:title={'center':'sepal_length'}>,
#         <AxesSubplot:title={'center':'sepal_width'}>],
#        [<AxesSubplot:title={'center':'petal_length'}>,
#         <AxesSubplot:title={'center':'petal_width'}>]], dtype=object)

# %%
# we can change the colour of the graph
df1.hist(figsize=(20,10),color='g')
# Out:
# array([[<AxesSubplot:title={'center':'sepal_length'}>,
#         <AxesSubplot:title={'center':'sepal_width'}>],
#        [<AxesSubplot:title={'center':'petal_length'}>,
#         <AxesSubplot:title={'center':'petal_width'}>]], dtype=object)

# %%
# intensity of color controlled by *alpha* it is range between 0-1
df1.hist(figsize=(20,10),color = "g",alpha = 0.2)
# Out:
# array([[<AxesSubplot:title={'center':'sepal_length'}>,
#         <AxesSubplot:title={'center':'sepal_width'}>],
#        [<AxesSubplot:title={'center':'petal_length'}>,
#         <AxesSubplot:title={'center':'petal_width'}>]], dtype=object)

# %%
df1.hist(figsize=(20,10),color = "g",alpha = .5)
# Out:
# array([[<AxesSubplot:title={'center':'sepal_length'}>,
#         <AxesSubplot:title={'center':'sepal_width'}>],
#        [<AxesSubplot:title={'center':'petal_length'}>,
#         <AxesSubplot:title={'center':'petal_width'}>]], dtype=object)

# %% [markdown]
# ### Box Graph :

# %%
# Box plot
df1.plot(kind='box',figsize = (20,10))
# Out:
# <AxesSubplot:>

# %%
df1.plot(kind='box',figsize = (20,10),color = {'boxes':"g","whiskers":'r'})
# Out:
# <AxesSubplot:>

# %%
df1.plot(kind='box',figsize = (20,10),color = {'boxes':"g","whiskers":'r'},vert = False)
# Out:
# <AxesSubplot:>

# %%
df1.plot.scatter(x="sepal_length",y="petal_length",c="sepal_width")
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
df1.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# ### Area Plot

# %%
df1.plot(kind="area",figsize=(20,10))
# Out:
# <AxesSubplot:>

# %%
df1.plot(kind="area",figsize=(20,10),alpha=.4,stacked=False)
# Out:
# <AxesSubplot:>

# %%
df1.plot(kind="area",figsize=(20,10),alpha=.4,stacked=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Scatter plot

# %%
df1.plot.scatter(x="sepal_length",y="petal_length",c="sepal_width")
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
df1.plot.scatter(x="sepal_length",y="petal_length")
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
df1.plot.scatter(x="sepal_length",y="petal_length",c="sepal_width",s=500)  # size of the dots are depends on s
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
df1.plot.scatter(x="sepal_length",y="petal_length",c="sepal_width",s = df1['petal_length']*500)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
df1.plot(kind = 'hexbin' , x='sepal_length', y = 'petal_length', gridsize = 10,c= "sepal_width")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13176/933667081.py in <module>
# ----> 1 df1.plot(kind = 'hexbin' , x='sepal_length', y = 'petal_length', gridsize = 10,c = "sepal_width")
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     915         if kind in self._dataframe_kinds:
#     916             if isinstance(data, ABCDataFrame):
# --> 917                 return plot_backend.plot(data, x=x, y=y, kind=kind, **kwargs)
#     918             else:
#     919                 raise ValueError(f"plot kind {kind} can only be used for data frames")
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_matplotlib\__init__.py in plot(data, kind, **kwargs)
#      69             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
df1=pd.read_csv('https://gist.githubusercontent.com/curran/a08a1080b88344b0c8a7/raw/0e7a9b0a5d22642a06d3d5b9bcbad9890c8ee534/iris.csv')

# %%
df1
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df1.drop(columns='species').iloc[0]
# Out:
# sepal_length    5.1
# sepal_width     3.5
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: float64

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2112/1014443466.py in <module>
# ----> 1 df1.plt(kind='species',x='sepal_length',y="petal_length ")
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'plt'

# %%
df = pd.read_csv('https://raw.githubusercontent.com/venky14/Machine-Learning-with-Iris-Dataset/master/Iris.csv')

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df = df.drop('Id',axis=1)

# %%
df
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df.plot.scatter(x = 'SepalLengthCm' , y = 'PetalLengthCm',c = 'SepalWidthCm',s = df['PetalWidthCm']*500)
# Out:
# <AxesSubplot:xlabel='SepalLengthCm', ylabel='PetalLengthCm'>

# %%
df.plot.hexbin(x='SepalLengthCm',y='PetalLengthCm',gridsize=10,c='SepalWidthCm')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2112/2817307520.py in <module>
# ----> 1 df.plot.hexbin(x='SepalLengthCm',y='PetalLengthCm',gridsize=10,c='SepalWidthCm')
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_core.py in hexbin(self, x, y, C, reduce_C_function, gridsize, **kwargs)
#    1723             kwargs["gridsize"] = gridsize
#    1724
# -> 1725         return self(kind="hexbin", x=x, y=y, C=C, **kwargs)
#    1726
#    1727
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     915         if kind in self._dataframe_kinds:
#     916             if isinstance(data, ABCDataFrame):
# --> 917                 return plot_backend.plot(data, x=x, y=y, kind=kind, **kwargs)
#     918             else:
# ...

# %%
df.plot.hexbin(x = 'SepalLengthCm' , y = 'PetalLengthCm' , gridsize= 10 ,C ='SepalWidthCm' )
# Out:
# <AxesSubplot:xlabel='SepalLengthCm', ylabel='PetalLengthCm'>

# %%
df.plot.scatter(x='SepalLengthCm',y='PetalLengthCm')
# Out:
# <AxesSubplot:xlabel='SepalLengthCm', ylabel='PetalLengthCm'>

# %%
df.head().plot(kind='pie')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2112/2836759641.py in <module>
# ----> 1 df.head().plot(kind='pie')
#
# ~\anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     921             if isinstance(data, ABCDataFrame):
#     922                 if y is None and kwargs.get("subplots") is False:
# --> 923                     raise ValueError(
#     924                         f"{kind} requires either y column or 'subplots=True'"
#     925                     )
#
# ValueError: pie requires either y column or 'subplots=True'

# %%
df
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df1 = df.drop(columns='Species').iloc[0]

# %%
df1.plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='0'>

# %%
df.drop(columns='Species').iloc[0]
# Out:
# SepalLengthCm    5.1
# SepalWidthCm     3.5
# PetalLengthCm    1.4
# PetalWidthCm     0.2
# Name: 0, dtype: float64

# %%
df1.plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='0'>

# %%
# !pip install plotly

# %%
# !pip install cufflinks
# Out:
# ...
#   Created wheel for cufflinks: filename=cufflinks-0.17.3-py3-none-any.whl size=68734 sha256=84eca2ca0a0486abb84fe27082573c9861e98e4c594eb7d4ffcc824ad776ffd2
#   Stored in directory: c:\users\lenovo\appdata\local\pip\cache\wheels\29\b4\f8\2fd2206eeeba6ccad8167e4e8894b8c4ec27bf1342037fd136
# Successfully built cufflinks
# ...

# %%
import cufflinks as cf

# %%
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.16.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
import pandas as pd 
import numpy as np
import matplotlib as plt

# %%
df = pd.read_csv('https://raw.githubusercontent.com/venky14/Machine-Learning-with-Iris-Dataset/master/Iris.csv')

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df.drop('Id',axis = 1)
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df.iplot()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\cufflinks\plotlytools.py in iplot(figure, validate, sharing, filename, online, asImage, asUrl, asPlot, dimensions, display_image, **kwargs)
#    1430                 try:
# -> 1431                         import chart_studio.plotly as py
#    1432                 except:
#
# ModuleNotFoundError: No module named 'chart_studio'
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_38056/4163631973.py in <module>
# ----> 1 df.iplot()
#
# ...

# %%
# !pip install chart_studio

# %%
df.iplot()
# Out:
# <div>                            <div id="87b90315-52c3-45fd-9192-1b0b34b3e633" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df= df.drop('Id',axis=1)

# %%
df
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df.iplot()
# Out:
# <div>                            <div id="2bb38d05-ffe5-475f-a3c2-8377e991d2fc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(x= 'SepalLengthCm',y='PetalLengthCm',mode='markers',kind='scatter')
# Out:
# <div>                            <div id="76f27b8d-fc6e-44ac-8e54-0668bb80164d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(kind='scatter',mode='markers',size=10)
# Out:
# <div>                            <div id="a422d656-28d1-4a1f-a7c4-83bf70f01674" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(kind='bubble',x= 'SepalLengthCm',y='PetalLengthCm',size='SepalWidthCm')
# Out:
# <div>                            <div id="9706f7cb-23dd-4d74-adc8-407bad3f2bdb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.scatter_matrix()
# Out:
# <div>                            <div id="4bd34acb-b0f1-4cee-bff7-3c2373f5e0c2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm         Species
# 0              5.1           3.5            1.4           0.2     Iris-setosa
# 1              4.9           3.0            1.4           0.2     Iris-setosa
# 2              4.7           3.2            1.3           0.2     Iris-setosa
# 3              4.6           3.1            1.5           0.2     Iris-setosa
# 4              5.0           3.6            1.4           0.2     Iris-setosa
# ..             ...           ...            ...           ...             ...
# 145            6.7           3.0            5.2           2.3  Iris-virginica
# 146            6.3           2.5            5.0           1.9  Iris-virginica
# 147            6.5           3.0            5.2           2.0  Iris-virginica
# 148            6.2           3.4            5.4           2.3  Iris-virginica
# 149            5.9           3.0            5.1           1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
df.iplot(kind='scatter3d',x= 'SepalLengthCm',y='SepalWidthCm',z='PetalLengthCm')
# Out:
# <div>                            <div id="918a15ad-380d-4ea6-9e4c-1843eaad970a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...
